# %%
from IPython.display import Image

# %%
Image('../../imgs/moe.png', width=500)

# %%
Image('../../imgs/gpt4-moe.png', width=500)

# %% [markdown]
# ## mixtral

# %% [markdown]
# - paper
#     - https://arxiv.org/pdf/2310.06825.pdf
#     - switch transformer
#         - https://arxiv.org/pdf/2101.03961.pdf
# - blog
#     - https://mistral.ai/news/mixtral-of-experts/
# - code
#     - https://github.com/mistralai/mistral-src/tree/main
#     - https://github.com/vikhyat/mixtral-inference/tree/main
# - huggingface
#     - https://huggingface.co/blog/mixtral
#     - https://medium.com/@martin-thissen/mixtral-8x7b-on-your-local-computer-free-gpt-4-alternative-e3cb301984e3
