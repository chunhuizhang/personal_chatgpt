# %%
from IPython.display import Image

# %% [markdown]
# ## basics

# %%
Image('../imgs/peft.png', width=400)

# %% [markdown]
# - Prefix Tuning
#     - 相当于在学前缀（也就是 prompt）
# - Adapter Tuning
#     - 串联式的；
# - LoRA
#     - 也是一种 Adapter
#     - 并联式的；

# %% [markdown]
# ## prefix tuning
