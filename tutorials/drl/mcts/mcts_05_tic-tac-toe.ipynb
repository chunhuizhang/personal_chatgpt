# %% [markdown]
# - references
#     - https://pastebin.com/bUcRrKwF
#         - https://www.youtube.com/watch?v=gvlO_-Fdk9w
#     - https://www.manifoldmadness.com/blog/mcts/monte-carlo-tree-search
#     - https://www.manifoldmadness.com/blog/mcts/integrating-mtcs-with-neural-networks
# - tictactoe: 3子棋
#     - two players，交互式的
#     - https://github.com/maksimKorzh/tictactoe-mtcs/blob/master/src/tictactoe/tictactoe.py
#         - https://www.youtube.com/watch?v=rY25jCtSidM
