# %%
from IPython.display import Image

# %% [markdown]
# - 参考
#     - https://github.com/FranxYao/chain-of-thought-hub
#     - 中文：
#         - https://yaofu.notion.site/C-Eval-6b79edd91b454e3d8ea41c59ea2af873

# %% [markdown]
# ## basics

# %% [markdown]
# - BERT、T5 pretrain dataset
#     - BookCorpus
#     - C4
#         - A significant proportion of the C4 corpus is machine-translated rather than
# translated by humans.
# - 几个方面（个人使用体验）
#     - 通用知识与常识（视为一个搜索引擎）
#
#         ```
#         prompt = """Q: Why is the sky blue?
#         A: """
#         ```
#         - `how many cars does it take to fly to the Mars?`
#
#     - 数学计算（基础的）
#     - 推理
#         ```
#         我6岁的时候,我妹妹只有我的一半大。现在我70岁了,我妹妹多大了?
#         ```
#     - 代码生成；
#
#         ```
#         prompt = """import matplotlib.pyplot as plt
#         """
#         ```

# %% [markdown]
# ## 评估数据集

# %% [markdown]
# - MMLU ：57个学科；
# - BBH：BIG-Bench Hard (BBH)
#     - https://arxiv.org/pdf/2210.09261.pdf
#     - includes 23 challenging tasks

# %% [markdown]
# - CEval
# - 悟道

# %% [markdown]
# - 数据泄露
# - 样本内泛化

# %% [markdown]
# - 评测榜单
#     - Huggingface

# %% [markdown]
# ## 具体指标

# %% [markdown]
# - unique tokens

# %%
Image('../imgs/unique-tokens.jpeg', width=600)

# %% [markdown]
# ## 可信（TruthfulQA）

# %% [markdown]
# - truthful_qa
#     - generation
#     - multiple choices
